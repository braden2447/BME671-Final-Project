# %% [markdown]
# # Test file
# ### Run any code you would like to test

# %%
# !pip install mne
import mne
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting mne
#   Downloading mne-1.2.2-py3-none-any.whl (7.6 MB)
# Requirement already satisfied: pooch>=1.5 in c:\users\brade\anaconda3\lib\site-packages (from mne) (1.6.0)
# Requirement already satisfied: decorator in c:\users\brade\anaconda3\lib\site-packages (from mne) (5.1.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\brade\anaconda3\lib\site-packages (from mne) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\brade\anaconda3\lib\site-packages (from mne) (3.5.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\brade\anaconda3\lib\site-packages (from mne) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\brade\anaconda3\lib\site-packages (from mne) (2.11.3)
# Requirement already satisfied: packaging in c:\users\brade\anaconda3\lib\site-packages (from mne) (21.3)
# Requirement already satisfied: tqdm in c:\users\brade\anaconda3\lib\site-packages (from mne) (4.64.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\brade\anaconda3\lib\site-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\brade\anaconda3\lib\site-packages (from pooch>=1.5->mne) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\brade\anaconda3\lib\site-packages (from packaging->mne) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\brade\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\brade\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\brade\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\brade\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\brade\anaconda3\lib\site-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\brade\anaconda3\lib\site-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\brade\anaconda3\lib\site-packages (from matplotlib->mne) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\brade\anaconda3\lib\site-packages (from matplotlib->mne) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\brade\anaconda3\lib\site-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\brade\anaconda3\lib\site-packages (from matplotlib->mne) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\brade\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mne) (1.16.0)
# Requirement already satisfied: colorama in c:\users\brade\anaconda3\lib\site-packages (from tqdm->mne) (0.4.4)
# Installing collected packages: mne
# Successfully installed mne-1.2.2

# %%
data = mne.io.read_raw_edf("data/n1.edf")
data.info
# Out:
# Extracting EDF parameters from /Users/jerryyang/Documents/python/BME671-Final-Project/data/n1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <Info | 7 non-empty values
#  bads: []
#  ch_names: ROC-LOC, LOC-ROC, F2-F4, F4-C4, C4-P4, P4-O2, F1-F3, F3-C3, ...
#  chs: 21 EEG
#  custom_ref_applied: False
#  highpass: 0.3 Hz
#  lowpass: 30.0 Hz
#  meas_date: 2009-01-01 22:06:03 UTC
#  nchan: 21
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
data.ch_names
# Out:
# ['ROC-LOC',
#  'LOC-ROC',
#  'F2-F4',
#  'F4-C4',
#  'C4-P4',
#  'P4-O2',
#  'F1-F3',
#  'F3-C3',
#  'C3-P3',
#  'P3-O1',
#  'C4-A1',
#  'EMG1-EMG2',
#  'ECG1-ECG2',
#  'TERMISTORE',
#  'TORACE',
#  'ADDOME',
#  'Dx1-DX2',
#  'SX1-SX2',
#  'Posizione',
#  'HR',
#  'SpO2']

# %% [markdown]
# > At least 3 EEG: F3 or F4, C3 or C4 and O1 or O2, referred to A1 or A2
#
# > Additional EEG bipolar traces: Fp1-F3, F3-C3, C3-P3, P3-O1 and/or Fp2-F4, F4-C4, C4-P4, P4-O2

# %%
raw_data = data.get_data()

# %%
fs = 512 #Hz
dt = 1/fs
t = np.arange(0, raw_data.shape[1]*dt, dt)

# %%
fig, ax = plt.subplots(7,3, figsize = (15,30))
for i in range(21):
    ax[i//3, i%3].plot(t, raw_data[i])
    ax[i//3, i%3].set_title(data.ch_names[i])
